# %% [markdown]
# ![IMG_3577.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IMG_3578.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Por ejemplo:
#
# Si el número es 1512131, entonces hay 3 unos (1).
#
#
#
# Así que el diagrama de flujo correcto para el punto c debe hacer esto paso a paso:
#
# Inicio
#
# Leer el número
#
# Inicializar contador = 0
#
# Mientras el número sea mayor que 0
#
#  ➡️ cifra = número mod 10
#
#  ➡️ Si cifra == 1, entonces contador = contador + 1
#
#  ➡️ número = número // 10 (división entera para quitar la última cifra)
#
# Mostrar cuántos “1” hay (contador)
#
# Fin
