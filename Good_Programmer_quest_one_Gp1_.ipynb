# %% [markdown]
# Talk to me los dos tutotriales

# %% [markdown]
# Congratulations! You've made your first app
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ball bounce

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Digital Doodle

# %% [markdown]
# 1.   Elemento de la lista![image.png](data:image/png;base64,...)
# 2.   Elemento de la lista
